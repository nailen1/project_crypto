# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
print(f"project root: {project_root}")

from crypto_strategy.universal_momentum.utils import get_momentum_6hr
# Out:
# project root: /Users/juneyoungpark/dev/project-crypto

# %%
p6hr = get_momentum_6hr()
p6hr

# %%
p6hr.loc['BTCUSDT'].iloc[0]

# %%
p6hr.head(50).plot.bar(figsize=(10, 5))
